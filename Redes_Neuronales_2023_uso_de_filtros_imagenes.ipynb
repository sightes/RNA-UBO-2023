# %% [markdown]
# <a href="https://colab.research.google.com/github/sightes/RNA-UBO-2023/blob/main/Redes_Neuronales_2023_uso_de_filtros_imagenes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
import tensorflow as tf
from keras.utils import load_img
from keras.utils import img_to_array
from keras.utils import array_to_img
from keras.models import Sequential
from keras.layers import Conv2D
import numpy as np

img = load_img('imagen.png', grayscale=True)
n=100
img = img.resize([n, n])
img.show()

# %%
input = keras.layers.Input(shape=(n,n,1), name='input')
# Definir el kernel del filtro de borde (operador de Sobel)
kernel_x= np.array([[-1, 0, 1],
                    [-2, 0, 2],
                    [-1, 0, 1]], dtype=np.float32)

kernel_y= np.array([[1, 1, 1],
                    [1, -8, 1],
                    [1, 1, 1]], dtype=np.float32)


init=tf.constant_initializer(kernel)
model = tf.keras.models.Sequential()
conv = tf.keras.layers.Conv2D(1, kernel_size=(3, 3), input_shape=(n, n, 1), padding='same', kernel_initializer=init, use_bias = False)(input)
model = tf.keras.models.Model(inputs=[input], outputs=conv, name='Color_Filter')
print(model.summary())
keras.utils.plot_model(model, show_shapes=True)

# %%
imagen=np.array(img)
imagen = imagen.reshape((1, n, n, 1))
img_out = model.predict([imagen])
img_out  = img_out.reshape((n,n))
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1,2)
ax[0].imshow(img)
ax[1].imshow(img_out)
# Out:
# 1/1 [==============================] - 0s 248ms/step

# %%
kernel_suavizado = np.ones((3, 3)) / 9



sigma = 1  # Parámetro de suavizado
kernel_gaussiano = np.fromfunction(lambda x, y: (1/(2*np.pi*sigma**2)) * np.exp(-((x-1)**2+(y-1)**2)/(2*sigma**2)), (3, 3))

kernel_contornos = np.array([[1, 1, 1],
                             [1, -8, 1],
                             [1, 1, 1]])


# Definir el kernel del filtro de Sobel en dirección X
kernel_sobel_x = np.array([[-1, 0, 1],
                           [-2, 0, 2],
                           [-1, 0, 1]])

# Definir el kernel del filtro de Sobel en dirección Y
kernel_sobel_y = np.array([[-1, -2, -1],
                           [0, 0, 0],
                           [1, 2, 1]])


# Definir el kernel del filtro de agudización
kernel_agudizacion = np.array([[0, -1, 0],
                               [-1, 5, -1],
                               [0, -1, 0]])


# Definir el kernel del filtro de realce de bordes
kernel_realce_bordes = np.array([[0, 1, 0],
                                 [1, -4, 1],
                                 [0, 1, 0]])

# Definir el kernel del filtro de emboss
kernel_emboss = np.array([[-2, -1, 0],
                          [-1, 1, 1],
                          [0, 1, 2]])
